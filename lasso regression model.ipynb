# %%
import pandas as pd

# %%
# for data visualization
import numpy as np
import seaborn as sea
import matplotlib.pyplot as plt

# %%
#load dataset
df = pd.read_csv("/Users/aman/Downloads/Algerian.csv",header=1)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
# check null values

df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df[df.isnull().any(axis =1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
#remove 122 row
df.drop(122).reset_index(drop=True)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 240  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 241  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 242  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 243  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 244  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
#row from 1 to 122 == 0 ,,,, 
df.loc[:122,'Region']=0
df.loc[167:,'Region']=1
df1=df

# %%
df1
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire        0.0
# ...

# %%
df1[['Region']]=df1[['Region']].fillna(0).astype(int)

# %%
df1[['Region']]
# Out:
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 241       1
# 242       1
# 243       1
# 244       1
# 245       1
#
# [246 rows x 1 columns]

# %%
df1=df1.dropna().reset_index(drop=True)

# %%
df1.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df1.drop(df1.index[-122],inplace= True)

# %%
df1
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          0
# ...

# %%
# remove particular column

# %%
#remove extra spaces from columnn
df1.columns = df.columns.str.strip()

# %%
df1.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df1.loc[:122]
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 117  26    09  2012          31  54  11     0    82    6  16.3  2.5  6.2  1.7
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
#
#          Classes  Region
# ...

# %%
print(df1.iloc[120:130])  # Check rows around index 122
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC    DC  ISI   BUI  FWI  \
# 120  29    09  2012          26  80  16  1.8  47.4  2.9   7.7  0.3     3  0.1
# 121  30    09  2012          25  78  14  1.4    45  1.9   7.5  0.2   2.4  0.1
# 123  01    06  2012          32  71  12  0.7  57.1  2.5   8.2  0.6   2.8  0.2
# 124  02    06  2012          30  73  13    4  55.7  2.7   7.8  0.6   2.9  0.2
# 125  03    06  2012          29  80  14    2  48.7  2.2   7.6  0.3   2.6  0.1
# 126  04    06  2012          30  64  14    0  79.4  5.2  15.4  2.2   5.6    1
# 127  05    06  2012          32  60  14  0.2  77.1    6  17.6  1.8   6.5  0.9
# 128  06    06  2012          35  54  11  0.1  83.7  8.4  26.3  3.1   9.3  3.1
# 129  07    06  2012          35  44  17  0.2  85.6  9.9  28.9  5.4  10.7    6
# 130  08    06  2012          28  51  17  1.3  71.4  7.7   7.4  1.5   7.3  0.8
#
#          Classes  Region
# 120  not fire          0
# 121  not fire          0
# 123  not fire          0
# ...

# %%
print(df.head())
print(df.info())
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
# ...

# %%
df1.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df1.columns= df1.columns.str.strip()
df1.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 38.5+ KB

# %%
# columns convert into integer
df1[['day','month','year','Temperature','RH','Ws']] = df1[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 38.5+ KB

# %%
# check the columns which is object type
objects = [feature for feature in df1.columns if df1[feature].dtype == 'O']
objects
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
df1[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']] = df1[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']].astype(float)

# %%
#for i in objects:
   # if i!= 'Columns':
       # df1[i] = df1[i].astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 38.5+ KB

# %%
df1.to_csv('/Users/aman/Desktop/EDA/Algerian forest.csv',index=False)

# %%
df1.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df1_copy = df1.drop(['day','month','year'],axis=1)

# %%
df1.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
df1_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df1_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df1_copy['Classes'] = np.where(df1_copy['Classes'].str.contains('not fire'), 0, 1)

# %%
df1_copy['Classes']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 239    1
# 240    0
# 241    0
# 242    0
# 243    0
# Name: Classes, Length: 243, dtype: int64

# %%
df1_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df1_copy.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 239           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 240           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 241           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 242           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 243           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 239       1
# 240       1
# 241       1
# 242       1
# 243       1

# %%
df1_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
# styles in matplotlib as seaborn 
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-bright')
df1_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
# class distribution
percentage = df1_copy['Classes'].value_counts(normalize = True)*100

# %%
percentage
# Out:
# Classes
# 1    56.378601
# 0    43.621399
# Name: proportion, dtype: float64

# %%
classlabels= ['fire','not_fire']
plt.figure(figsize =(5,2))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%',colors=['red', 'green'])
plt.title("pie chart of classes")
plt.show()

# %%
df1_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
 sea.heatmap(df1_copy.corr(),annot=True)
# Out:
# <Axes: >

# %%
sea.boxplot(df1_copy['Temperature'],color='green')
# Out:
# <Axes: ylabel='Temperature'>

# %%
df1_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df1_copy.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 239           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 240           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 241           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 242           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 243           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 239       1
# 240       1
# 241       1
# 242       1
# 243       1

# %%
dftemp =df1_copy.loc[df1_copy['Region']==0]
plt.subplots(figsize=(13,5))
sea.set_style("ticks")
sea.countplot(x='month',hue='Region',data=df1)
plt.ylabel("no of fires",weight = 'bold')
plt.xlabel("Months",weight = 'bold')
plt.title("Fire analysis algerna forest",weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Fire analysis algerna forest')

# %%
dftemp =df1.loc[df1['Region']==0]
plt.subplots(figsize=(13,5))
sea.set_style("whitegrid")
sea.countplot(x='month',hue='Classes',data=df1)
plt.ylabel("no of fires",weight = 'bold')
plt.xlabel("Months",weight = 'bold')
plt.title("Fire analysis algerna forest",weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Fire analysis algerna forest')

# %%
## Independent And dependent features
X=df1_copy.drop('FWI',axis=1)
y=df1_copy['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y.head(243)
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 239    6.5
# 240    0.0
# 241    0.2
# 242    0.7
# 243    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
X.shape, y.shape
# Out:
# ((243, 11), (243,))

# %%
from sklearn.model_selection import train_test_split
X_train , X_test ,y_train ,y_test = train_test_split(X,y,test_size= 0.25,random_state = 42)

# %%
X_train.shape
# Out:
# (182, 11)

# %%
y_train.shape
# Out:
# (182,)

# %%
X_train.info()
X_train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 97 to 102
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  182 non-null    int64
#  1   RH           182 non-null    int64
#  2   Ws           182 non-null    int64
#  3   Rain         182 non-null    float64
#  4   FFMC         182 non-null    float64
#  5   DMC          182 non-null    float64
#  6   DC           182 non-null    float64
#  7   ISI          182 non-null    float64
#  8   BUI          182 non-null    float64
#  9   Classes      182 non-null    int64
#  10  Region       182 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 17.1 KB
#        Temperature          RH          Ws        Rain        FFMC  \
# count   182.000000  182.000000  182.000000  182.000000  182.000000
# mean     32.115385   62.274725   15.576923    0.820879   77.633516
# std       3.706480   15.014590    2.640968    2.143267   14.357601
# ...

# %%
## Feature Selection based on correlaltion
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.261028 -0.315323 -0.147257 -0.147914  0.292952  0.362108
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
print(y_train,X_train)
# Out:
# 97      0.9
# 142     0.3
# 193    21.6
# 68      2.6
# 119     0.9
#        ...
# 106     0.0
# 14      0.1
# 92      0.1
# 180    10.9
# 102     0.3
# Name: FWI, Length: 182, dtype: float64      Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI   BUI  Classes  Region
# 97            29  74  19   0.1  75.8   3.6  32.2   2.1   5.6        0       0
# 142           31  72  14   0.2  60.2   3.8   8.0   0.8   3.7        0       0
# 193           40  31  15   0.0  94.2  22.5  46.3  16.6  22.4        1       1
# 68            32  60  18   0.3  77.1  11.3  47.0   2.2  14.1        0       0
# 119           32  47  14   0.7  77.5   7.1   8.8   1.8   6.8        0       0
# ..           ...  ..  ..   ...   ...   ...   ...   ...   ...      ...     ...
# 106           24  82  15   0.4  44.9   0.9   7.3   0.2   1.4        0       0
# 14            28  80  17   3.1  49.4   3.0   7.4   0.4   3.0        0       0
# 92            25  76  17   7.2  46.0   1.3   7.5   0.2   1.8        0       0
# ...

# %%
## Check for multicollinearity
plt.figure(figsize=(12,10))
corr=X_train.corr()
sea.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset, threshold):   # create function 
    col_corr = set()                   # seat value function 
    corr_matrix = dataset.corr()       # dataset(X_train) coreleation
    for i in range(len(corr_matrix.columns)):    # store the values which are graeater than threshold value(0.85)
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:   
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold--Domain expertise
corr_features=correlation(X_train,0.85)     # threshold = 0.85

# %%
corr_features
# Out:
# {'BUI', 'DC'}

# %%
## drop features when correlation is more than 0.85
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.261028 -0.315323 -0.147257 -0.147914  0.292952  0.362108
#
#                   ISI   Classes    Region
# Temperature  0.629848  0.542141  0.261028
# RH          -0.717804 -0.456876 -0.315323
# Ws          -0.023558 -0.082570 -0.147257
# Rain        -0.345707 -0.369357 -0.147914
# ...

# %% [markdown]
# ##Feature Scaling Or Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -0.69258559],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526, -0.69258559],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  1.44386487],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -0.69258559],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  1.44386487],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -0.69258559]])

# %%
X_test_scaled
# Out:
# array([[-3.01758418e-01,  1.15223531e-01, -2.19053977e-01,
#         -3.84060174e-01,  6.33218240e-01, -4.25075679e-02,
#          2.03772218e-01,  9.05538514e-01, -6.92585588e-01],
#        [ 2.39325642e-01, -5.52632606e-01, -9.78441098e-01,
#         -3.84060174e-01,  7.37980727e-01, -3.83352062e-01,
#          3.65823283e-01,  9.05538514e-01, -6.92585588e-01],
#        [-1.11338451e+00, -2.85490151e-01,  9.20026704e-01,
#          6.45241658e-01, -9.73139891e-01, -9.14435344e-01,
#         -8.37984627e-01, -1.10431526e+00, -6.92585588e-01],
#        [ 5.09867672e-01, -2.85490151e-01, -9.78441098e-01,
#         -2.90487280e-01,  1.30358303e-01,  3.14190159e-01,
#         -6.29633258e-01, -1.10431526e+00,  1.44386487e+00],
#        [-5.72300448e-01,  1.82009145e-01, -5.98747538e-01,
#         -3.84060174e-01,  5.42424085e-01,  1.00171523e-01,
#         -7.40296073e-02,  9.05538514e-01,  1.44386487e+00],
#        [ 1.86257782e+00,  1.15223531e-01, -2.49721534e+00,
# ...

# %% [markdown]
# Box Plots To understand Effect Of Standard Scaler

# %%
plt.subplots(figsize=(20, 10))
plt.subplot(1, 2, 1)                   # 1 row 2 column 1st box
sea.boxplot(data=X_train)
plt.title('X_train Before Scaling')
plt.subplot(1, 2, 2)
sea.boxplot(data=X_train_scaled)
plt.title('X_train After Scaling')
# Out:
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
linreg=LinearRegression()

# %%
linreg.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(X_test_scaled)
mae = mean_absolute_error(y_pred,y_test)
score = r2_score(y_pred,y_test)
print("mae =", mae)
print("score =",score)
# Out:
# mae = 0.5736390844747599
# score = 0.9831664907948948

# %% [markdown]
# LASSO REGRESSION

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso=Lasso()
#lasso.fit(X_train_scaled,y_train)
lasso.fit(X_train_scaled,y_train)
y_pred=lasso.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 1.1331759949144082
# R2 Score 0.9492020263112388

# %% [markdown]
# Ridge Regression model

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.5897721674683631
# R2 Score 0.9834340751893448

# %% [markdown]
# Elasticnet Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elastic=ElasticNet()
elastic.fit(X_train_scaled,y_train)
y_pred=elastic.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 1.8824581988028912
# R2 Score 0.8752065783606924

# %%
import pickle
pickle.dump(scaler,open('/Users/aman/Desktop/EDA/scaler.pkl','wb'))   # standard scaler for feature scaling
pickle.dump(ridge,open('/Users/aman/Desktop/EDA/ridge.pkl','wb'))     # ridge regression model for model training

# %%
with open('/Users/aman/Desktop/EDA/scaler.pkl','rb') as file1,open('/Users/aman/Desktop/EDA/ridge.pkl','rb') as file2:
    scaler = pickle.load(file1)
    ridge = pickle.load(file2)
    print(scaler)
    print(ridge)
# Out:
# StandardScaler()
# Ridge()
